# %%
import tensorflow as tf
import numpy as np
import cv2

print("✅ TensorFlow:", tf.__version__)
print("✅ NumPy:", np.__version__)
print("✅ OpenCV:", cv2.__version__)
print("🎉 VS Code + cropenv connected!")
# Out:
# ✅ TensorFlow: 2.16.2
# ✅ NumPy: 1.26.4
# ✅ OpenCV: 4.8.1
# 🎉 VS Code + cropenv connected!
